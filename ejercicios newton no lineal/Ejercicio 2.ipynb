# %%
import numpy as np
import math
def jacobiano(x):
    J = np.array([[1-2*x[0],4],[2*(x[0]-2),4*(2*x[1]-3)]])
    JInversa = np.linalg.inv(J)
    return JInversa

def Fx(x):
    x1 =x[0]*(1-x[0])+4*x[1]-12
    x2=(x[0]-2)**2+(2*x[1]-3)**2-25
    xk = np.array([x1,x2])
    return xk
x = np.array([0,0]) #vector de valores iniciales
error = 1
c=0
maxiter=int(input('introduzca numero de iteraciones'))
iteraciones=0
while error>0.01 and iteraciones<maxiter:
    iteraciones+=1
    c+=1
    r= jacobiano(x)
    feval = Fx(x)
    resultado =x- np.dot(r,feval)
    
    numerador = np.amax( abs((resultado - x)))
    denominador = np.amax( abs(resultado))
    error = numerador/denominador
    x=resultado
    
    print("Iteración:",c," Resultado ",resultado)
# Out:
# introduzca numero de iteraciones10
# Iteración: 1  Resultado  [-48.  15.]
# Iteración: 2  Resultado  [-23.94262597   7.60867966]
# Iteración: 3  Resultado  [-11.82160063   4.16314669]
# Iteración: 4  Resultado  [-5.67345489  3.0154623 ]
# Iteración: 5  Resultado  [-2.68618847  3.24450909]
# Iteración: 6  Resultado  [-1.41209067  3.44569138]
# Iteración: 7  Resultado  [-1.0388125   3.49465183]
# Iteración: 8  Resultado  [-1.0004157   3.49994324]
# Iteración: 9  Resultado  [-1.00000005  3.49999999]
